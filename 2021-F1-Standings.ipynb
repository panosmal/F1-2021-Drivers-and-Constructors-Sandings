# %%
import pandas as pd
import numpy as np
from numpy import linalg
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from IPython.display import display
from IPython.display import display_html



# Load the data
data=pd.read_excel('F1 RACES 2021.xlsx',index_col=None,header=None)
races=data.iloc[1:,2:].reset_index(drop=True)
m=races.shape[0]
n=races.shape[1]
races.set_axis(list(range(n)), axis=1, inplace=True)
races=np.array(races)

# %% [markdown]
# # Who beat who matrix

# %%
scores=np.zeros((m,m))
teams_score=np.zeros(10)


# Here we create a matrix of 'who beat who'. Every driver   
# receives 1 point for any driver finished in a lower position 
for i in range(m):
    for j in range(i,m):
        if i==j:
            scores[i,j]=0
        else:
            scores[i,j]=len(np.where(races[i,:]<races[j,:])[0])
            scores[j,i]=n-scores[i,j]
            
driver_score=scores.astype('int') # keep every driver's points array, for each Grand Prix 

# Calculate a matrix of teams' scores by summing the points of each team's driver
teams=['Alfa Romeo Racing Ferrari', 'AlphaTauri Honda', 'Alpine Renault', 'Aston Martin Mercedes', 'Ferrari', 
       'Haas Ferrari', 'McLaren Mercedes', 'Mercedes', 'Red Bull Racing Honda', 'Williams Mercedes']

for i in range(len(teams)):
    for j in range(1,m+1):
        if data.iloc[j,1]==teams[i]:
            teams_score[i] += np.sum(scores[j-1,:])
teams_results={}
for i in range(len(teams)):
    teams_results.update({teams[i]:teams_score[i]})

# %%
teams_score = teams_score.astype('int')

# %% [markdown]
# # PageRank algorithm

# %%
# The PageRank Method for drivers points
for i in range(m):
    scores[i,:]=scores[i,:]/np.sum(scores[i,:])
a=0.85
G=a*scores+(1-a)*(np.ones((m,m))/m)


k=0
E,V=np.linalg.eig(G)
x=np.ones((21))
old_eig_value=0
# Find the nomber k of iterations necessary to reach convergence
for i in range(100):
    x=np.dot(G,x)
    eig_value=np.linalg.norm(x)
    error=np.abs((eig_value-old_eig_value)/eig_value)
    x=x/eig_value
    if error<0.05:
        break
    old_eig_value=eig_value
    k+=1   

q=(np.ones((1,m)))/m@ G**k

# %%
# Calculate and display the final standings of both teams and drivers
q=q.T
names=data.iloc[1:,0]
names=names.to_numpy()
results={}
for i in range(m):
    results.update({names[i]:q[i]})

# %% [markdown]
# # Web scraping F1 drivers' final rankings

# %%
import requests
# Scaping driver data
driver_standings_url = 'https://www.formula1.com/en/results.html/2021/drivers.html'
driver_url_data = requests.get(driver_standings_url)

from bs4 import BeautifulSoup
driver_soup = BeautifulSoup(driver_url_data.text)
table = driver_soup.select('table.resultarchive-table')
drivers_table=pd.read_html(driver_url_data.text, index_col=1)[0]

# %%
drivers_table
# Out:
#      Unnamed: 0                    Driver Nationality  \
# Pos
# 1           NaN      Max  Verstappen  VER         NED
# 2           NaN      Lewis  Hamilton  HAM         GBR
# 3           NaN     Valtteri  Bottas  BOT         FIN
# 4           NaN        Sergio  Perez  PER         MEX
# 5           NaN        Carlos  Sainz  SAI         ESP
# 6           NaN        Lando  Norris  NOR         GBR
# 7           NaN     Charles  Leclerc  LEC         MON
# 8           NaN    Daniel  Ricciardo  RIC         AUS
# 9           NaN        Pierre  Gasly  GAS         FRA
# 10          NaN     Fernando  Alonso  ALO         ESP
# 11          NaN        Esteban  Ocon  OCO         FRA
# 12          NaN    Sebastian  Vettel  VET         GER
# 13          NaN        Lance  Stroll  STR         CAN
# 14          NaN        Yuki  Tsunoda  TSU         JPN
# 15          NaN      George  Russell  RUS         GBR
# 16          NaN    Kimi  RÃ¤ikkÃ¶nen  RAI         FIN
# 17          NaN     Nicholas  Latifi  LAT         CAN
# 18          NaN  Antonio  Giovinazzi  GIO         ITA
# 19          NaN     Mick  Schumacher  MSC         GER
# 20          NaN       Robert  Kubica  KUB         POL
# 21          NaN      Nikita  Mazepin  MAZ         RAF
#
#                            Car    PTS  Unnamed: 6
# Pos
# 1        Red Bull Racing Honda  395.5         NaN
# 2                     Mercedes  387.5         NaN
# 3                     Mercedes  226.0         NaN
# 4        Red Bull Racing Honda  190.0         NaN
# 5                      Ferrari  164.5         NaN
# 6             McLaren Mercedes  160.0         NaN
# 7                      Ferrari  159.0         NaN
# 8             McLaren Mercedes  115.0         NaN
# 9             AlphaTauri Honda  110.0         NaN
# 10              Alpine Renault   81.0         NaN
# 11              Alpine Renault   74.0         NaN
# 12       Aston Martin Mercedes   43.0         NaN
# 13       Aston Martin Mercedes   34.0         NaN
# 14            AlphaTauri Honda   32.0         NaN
# 15           Williams Mercedes   16.0         NaN
# 16   Alfa Romeo Racing Ferrari   10.0         NaN
# 17           Williams Mercedes    7.0         NaN
# 18   Alfa Romeo Racing Ferrari    3.0         NaN
# 19                Haas Ferrari    0.0         NaN
# 20   Alfa Romeo Racing Ferrari    0.0         NaN
# 21                Haas Ferrari    0.0         NaN

# %%
drivers_table = drivers_table.drop(['Unnamed: 0','Nationality','Car','Unnamed: 6'], axis=1) #remove unnamed, Nationality & car columns
drivers_table['Driver'] = drivers_table['Driver'].map(lambda x: str(x)[:-4])
drivers_table.at[16, 'Driver'] = 'Kimi Raikkonen'   # set Kimi's name right
drivers_table['PTS'] = drivers_table['PTS'].apply(lambda x: '%.1f' % x)

# %% [markdown]
# # World Drivers' Championship standings

# %%
final_results=dict(sorted(results.items(), key=lambda x:x[1]))

total_points = sorted(np.sum(driver_score, axis=1).tolist(), reverse = True) #total driver's sum of points 

a1=np.arange(1,m+1)
drivers_data=pd.DataFrame({'Pos':list(a1), 'Driver':final_results.keys(), 'PTS':total_points}).set_index('Pos')

# %%
drivers_table = drivers_table.style.set_table_attributes("style='display:inline; margin-right:100px;'").set_caption('F1 2021 Drivers\' Standings - '
                                                         'Real Data').set_table_styles([{'selector':'caption', 
'props':[('font-size', '14px'), ('text-align','center'), ('color','black'), ('font-style', 'italic'), ('font-weight', 'bold')] }])
drivers_data = drivers_data.style.set_table_attributes("style='display:inline'").set_caption('F1 2021 Drivers\' '
                                                                                             'Standings - PageRank').set_table_styles([{'selector':'caption', 
'props':[('font-size', '14px'), ('text-align','center'), 
         ('color','black'), ('font-style', 'italic'), ('font-weight', 'bold')] }])

# %%
display_html(drivers_table._repr_html_() + drivers_data._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# #T_bf3bc caption {
#   font-size: 14px;
#   text-align: center;
#   color: black;
#   font-style: italic;
#   font-weight: bold;
# }
# </style>
# <table id="T_bf3bc" style='display:inline; margin-right:100px;'>
#   <caption>F1 2021 Drivers' Standings - Real Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf3bc_level0_col0" class="col_heading level0 col0" >Driver</th>
#       <th id="T_bf3bc_level0_col1" class="col_heading level0 col1" >PTS</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pos</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf3bc_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_bf3bc_row0_col0" class="data row0 col0" >Max  Verstappen </td>
#       <td id="T_bf3bc_row0_col1" class="data row0 col1" >395.5</td>
#     </tr>
#     <tr>
#       <th id="T_bf3bc_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_bf3bc_row1_col0" class="data row1 col0" >Lewis  Hamilton </td>
#       <td id="T_bf3bc_row1_col1" class="data row1 col1" >387.5</td>
#     </tr>
#     <tr>
#       <th id="T_bf3bc_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_bf3bc_row2_col0" class="data row2 col0" >Valtteri  Bottas </td>
#       <td id="T_bf3bc_row2_col1" class="data row2 col1" >226.0</td>
#     </tr>
#     <tr>
#       <th id="T_bf3bc_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_bf3bc_row3_col0" class="data row3 col0" >Sergio  Perez </td>
#       <td id="T_bf3bc_row3_col1" class="data row3 col1" >190.0</td>
#     </tr>
#     <tr>
#       <th id="T_bf3bc_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_bf3bc_row4_col0" class="data row4 col0" >Carlos  Sainz </td>
#       <td id="T_bf3bc_row4_col1" class="data row4 col1" >164.5</td>
#     </tr>
#     <tr>
#       <th id="T_bf3bc_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_bf3bc_row5_col0" class="data row5 col0" >Lando  Norris </td>
#       <td id="T_bf3bc_row5_col1" class="data row5 col1" >160.0</td>
#     </tr>
#     <tr>
#       <th id="T_bf3bc_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_bf3bc_row6_col0" class="data row6 col0" >Charles  Leclerc </td>
#       <td id="T_bf3bc_row6_col1" class="data row6 col1" >159.0</td>
#     </tr>
#     <tr>
#       <th id="T_bf3bc_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_bf3bc_row7_col0" class="data row7 col0" >Daniel  Ricciardo </td>
#       <td id="T_bf3bc_row7_col1" class="data row7 col1" >115.0</td>
#     </tr>
#     <tr>
#       <th id="T_bf3bc_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_bf3bc_row8_col0" class="data row8 col0" >Pierre  Gasly </td>
#       <td id="T_bf3bc_row8_col1" class="data row8 col1" >110.0</td>
#     </tr>
#     <tr>
#       <th id="T_bf3bc_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_bf3bc_row9_col0" class="data row9 col0" >Fernando  Alonso </td>
#       <td id="T_bf3bc_row9_col1" class="data row9 col1" >81.0</td>
#     </tr>
#     <tr>
#       <th id="T_bf3bc_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_bf3bc_row10_col0" class="data row10 col0" >Esteban  Ocon </td>
#       <td id="T_bf3bc_row10_col1" class="data row10 col1" >74.0</td>
#     </tr>
#     <tr>
#       <th id="T_bf3bc_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_bf3bc_row11_col0" class="data row11 col0" >Sebastian  Vettel </td>
#       <td id="T_bf3bc_row11_col1" class="data row11 col1" >43.0</td>
#     </tr>
#     <tr>
#       <th id="T_bf3bc_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_bf3bc_row12_col0" class="data row12 col0" >Lance  Stroll </td>
#       <td id="T_bf3bc_row12_col1" class="data row12 col1" >34.0</td>
#     </tr>
#     <tr>
#       <th id="T_bf3bc_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_bf3bc_row13_col0" class="data row13 col0" >Yuki  Tsunoda </td>
#       <td id="T_bf3bc_row13_col1" class="data row13 col1" >32.0</td>
#     </tr>
#     <tr>
#       <th id="T_bf3bc_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_bf3bc_row14_col0" class="data row14 col0" >George  Russell </td>
#       <td id="T_bf3bc_row14_col1" class="data row14 col1" >16.0</td>
#     </tr>
#     <tr>
#       <th id="T_bf3bc_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_bf3bc_row15_col0" class="data row15 col0" >Kimi Raikkonen</td>
#       <td id="T_bf3bc_row15_col1" class="data row15 col1" >10.0</td>
#     </tr>
#     <tr>
#       <th id="T_bf3bc_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_bf3bc_row16_col0" class="data row16 col0" >Nicholas  Latifi </td>
#       <td id="T_bf3bc_row16_col1" class="data row16 col1" >7.0</td>
#     </tr>
#     <tr>
#       <th id="T_bf3bc_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_bf3bc_row17_col0" class="data row17 col0" >Antonio  Giovinazzi </td>
#       <td id="T_bf3bc_row17_col1" class="data row17 col1" >3.0</td>
#     </tr>
#     <tr>
#       <th id="T_bf3bc_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_bf3bc_row18_col0" class="data row18 col0" >Mick  Schumacher </td>
#       <td id="T_bf3bc_row18_col1" class="data row18 col1" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_bf3bc_level0_row19" class="row_heading level0 row19" >20</th>
#       <td id="T_bf3bc_row19_col0" class="data row19 col0" >Robert  Kubica </td>
#       <td id="T_bf3bc_row19_col1" class="data row19 col1" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_bf3bc_level0_row20" class="row_heading level0 row20" >21</th>
#       <td id="T_bf3bc_row20_col0" class="data row20 col0" >Nikita  Mazepin </td>
#       <td id="T_bf3bc_row20_col1" class="data row20 col1" >0.0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_cbad6 caption {
#   font-size: 14px;
#   text-align: center;
#   color: black;
#   font-style: italic;
#   font-weight: bold;
# }
# </style>
# <table id="T_cbad6" style='display:inline'>
#   <caption>F1 2021 Drivers' Standings - PageRank</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbad6_level0_col0" class="col_heading level0 col0" >Driver</th>
#       <th id="T_cbad6_level0_col1" class="col_heading level0 col1" >PTS</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pos</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbad6_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_cbad6_row0_col0" class="data row0 col0" >Lewis Hamilton</td>
#       <td id="T_cbad6_row0_col1" class="data row0 col1" >387</td>
#     </tr>
#     <tr>
#       <th id="T_cbad6_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_cbad6_row1_col0" class="data row1 col0" >Max Verstappen</td>
#       <td id="T_cbad6_row1_col1" class="data row1 col1" >371</td>
#     </tr>
#     <tr>
#       <th id="T_cbad6_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_cbad6_row2_col0" class="data row2 col0" >Carlos Sainz</td>
#       <td id="T_cbad6_row2_col1" class="data row2 col1" >319</td>
#     </tr>
#     <tr>
#       <th id="T_cbad6_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_cbad6_row3_col0" class="data row3 col0" >Lando Norris</td>
#       <td id="T_cbad6_row3_col1" class="data row3 col1" >308</td>
#     </tr>
#     <tr>
#       <th id="T_cbad6_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_cbad6_row4_col0" class="data row4 col0" >Sergio Perez</td>
#       <td id="T_cbad6_row4_col1" class="data row4 col1" >299</td>
#     </tr>
#     <tr>
#       <th id="T_cbad6_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_cbad6_row5_col0" class="data row5 col0" >Charles Leclerc</td>
#       <td id="T_cbad6_row5_col1" class="data row5 col1" >296</td>
#     </tr>
#     <tr>
#       <th id="T_cbad6_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_cbad6_row

# %% [markdown]
# # Web scraping F1 Constructors' final rankings

# %%
# Scaping teams' data
teams_standings_url = 'https://www.formula1.com/en/results.html/2021/team.html'
teams_url_data = requests.get(teams_standings_url)

from bs4 import BeautifulSoup
teams_soup = BeautifulSoup(teams_url_data.text)
tm_table = teams_soup.select('table.resultarchive-table')
teams_table=pd.read_html(teams_url_data.text, index_col=1)[0]

# %%
teams_table
# Out:
#      Unnamed: 0                       Team    PTS  Unnamed: 4
# Pos
# 1           NaN                   Mercedes  613.5         NaN
# 2           NaN      Red Bull Racing Honda  585.5         NaN
# 3           NaN                    Ferrari  323.5         NaN
# 4           NaN           McLaren Mercedes  275.0         NaN
# 5           NaN             Alpine Renault  155.0         NaN
# 6           NaN           AlphaTauri Honda  142.0         NaN
# 7           NaN      Aston Martin Mercedes   77.0         NaN
# 8           NaN          Williams Mercedes   23.0         NaN
# 9           NaN  Alfa Romeo Racing Ferrari   13.0         NaN
# 10          NaN               Haas Ferrari    0.0         NaN

# %%
teams_table = teams_table.drop(['Unnamed: 0','Unnamed: 4'], axis=1) #remove unnamed columns
teams_table['PTS'] = teams_table['PTS'].apply(lambda x: '%.1f' % x) #format points with 1 decimal digit

# %% [markdown]
# # World Constructors' Championship standings

# %%
final_teams=dict(sorted(teams_results.items(), key=lambda x:x[1], reverse=True))
team_points = sorted(teams_score.tolist(), reverse = True)

teams_data=pd.DataFrame({'Pos':list(np.arange(1,11)), 'Team':final_teams.keys(), 
                         'PTS':team_points}).set_index('Pos')
teams_data=teams_data.style.set_table_attributes("style='display:inline; margin-right:100px;'").set_caption('F1 2021 Constructors\' Standings - '
                                                         'PageRank').set_table_styles([{'selector':'caption', 
'props':[('font-size', '14px'), ('text-align','center'), ('color','black'), ('font-style', 'italic'), ('font-weight', 'bold')] }])

teams_table = teams_table.style.set_table_attributes("style='display:inline; margin-right:100px;'").set_caption('F1 2021 Constructors\' Standings - '
                                                         'Real Data').set_table_styles([{'selector':'caption', 
'props':[('font-size', '14px'), ('text-align','center'), ('color','black'), ('font-style', 'italic'), ('font-weight', 'bold')] }])

# %%
display_html(teams_table._repr_html_() + teams_data._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# #T_fe759 caption {
#   font-size: 14px;
#   text-align: center;
#   color: black;
#   font-style: italic;
#   font-weight: bold;
# }
# </style>
# <table id="T_fe759" style='display:inline; margin-right:100px;'>
#   <caption>F1 2021 Constructors' Standings - Real Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe759_level0_col0" class="col_heading level0 col0" >Team</th>
#       <th id="T_fe759_level0_col1" class="col_heading level0 col1" >PTS</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pos</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe759_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_fe759_row0_col0" class="data row0 col0" >Mercedes</td>
#       <td id="T_fe759_row0_col1" class="data row0 col1" >613.5</td>
#     </tr>
#     <tr>
#       <th id="T_fe759_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_fe759_row1_col0" class="data row1 col0" >Red Bull Racing Honda</td>
#       <td id="T_fe759_row1_col1" class="data row1 col1" >585.5</td>
#     </tr>
#     <tr>
#       <th id="T_fe759_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_fe759_row2_col0" class="data row2 col0" >Ferrari</td>
#       <td id="T_fe759_row2_col1" class="data row2 col1" >323.5</td>
#     </tr>
#     <tr>
#       <th id="T_fe759_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_fe759_row3_col0" class="data row3 col0" >McLaren Mercedes</td>
#       <td id="T_fe759_row3_col1" class="data row3 col1" >275.0</td>
#     </tr>
#     <tr>
#       <th id="T_fe759_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_fe759_row4_col0" class="data row4 col0" >Alpine Renault</td>
#       <td id="T_fe759_row4_col1" class="data row4 col1" >155.0</td>
#     </tr>
#     <tr>
#       <th id="T_fe759_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_fe759_row5_col0" class="data row5 col0" >AlphaTauri Honda</td>
#       <td id="T_fe759_row5_col1" class="data row5 col1" >142.0</td>
#     </tr>
#     <tr>
#       <th id="T_fe759_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_fe759_row6_col0" class="data row6 col0" >Aston Martin Mercedes</td>
#       <td id="T_fe759_row6_col1" class="data row6 col1" >77.0</td>
#     </tr>
#     <tr>
#       <th id="T_fe759_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_fe759_row7_col0" class="data row7 col0" >Williams Mercedes</td>
#       <td id="T_fe759_row7_col1" class="data row7 col1" >23.0</td>
#     </tr>
#     <tr>
#       <th id="T_fe759_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_fe759_row8_col0" class="data row8 col0" >Alfa Romeo Racing Ferrari</td>
#       <td id="T_fe759_row8_col1" class="data row8 col1" >13.0</td>
#     </tr>
#     <tr>
#       <th id="T_fe759_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_fe759_row9_col0" class="data row9 col0" >Haas Ferrari</td>
#       <td id="T_fe759_row9_col1" class="data row9 col1" >0.0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e486c caption {
#   font-size: 14px;
#   text-align: center;
#   color: black;
#   font-style: italic;
#   font-weight: bold;
# }
# </style>
# <table id="T_e486c" style='display:inline; margin-right:100px;'>
#   <caption>F1 2021 Constructors' Standings - PageRank</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e486c_level0_col0" class="col_heading level0 col0" >Team</th>
#       <th id="T_e486c_level0_col1" class="col_heading level0 col1" >PTS</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pos</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e486c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e486c_row0_col0" class="data row0 col0" >Mercedes</td>
#       <td id="T_e486c_row0_col1" class="data row0 col1" >686</td>
#     </tr>
#     <tr>
#       <th id="T_e486c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_e486c_row1_col0" class="data row1 col0" >Red Bull Racing Honda</td>
#       <td id="T_e486c_row1_col1" class="data row1 col1" >667</td>
#     </tr>
#     <tr>
#       <th id="T_e486c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_e486c_row2_col0" class="data row2 col0" >Ferrari</td>
#       <td id="T_e486c_row2_col1" class="data row2 col1" >611</td>
#     </tr>
#     <tr>
#       <th id="T_e486c_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_e486c_row3_col0" class="data row3 col0" >McLaren Mercedes</td>
#       <td id="T_e486c_row3_col1" class="data row3 col1" >581</td>
#     </tr>
#     <tr>
#       <th id="T_e486c_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_e486c_row4_col0" class="data row4 col0" >Alpine Renault</td>
#       <td id="T_e486c_row4_col1" class="data row4 col1" >473</td>
#     </tr>
#     <tr>
#       <th id="T_e486c_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_e486c_row5_col0" class="data row5 col0" >AlphaTauri Honda</td>
#       <td id="T_e486c_row5_col1" class="data row5 col1" >428</td>
#     </tr>
#     <tr>
#       <th id="T_e486c_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_e486c_row6_col0" class="data row6 col0" >Aston Martin Mercedes</td>
#       <td id="T_e486c_row6_col1" class="data row6 col1" >396</td>
#     </tr>
#     <tr>
#       <th id="T_e486c_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_e486c_row7_col0" class="data row7 col0" >Alfa Romeo Racing Ferrari</td>
#       <td id="T_e486c_row7_col1" class="data row7 col1" >343</td>
#     </tr>
#     <tr>
#       <th id="T_e486c_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_e486c_row8_col0" class="data row8 col0" >Williams Mercedes</td>
#       <td id="T_e486c_row8_col1" class="data row8 col1" >276</td>
#     </tr>
#     <tr>
#       <th id="T_e486c_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_e486c_row9_col0" class="data row9 col0" >Haas Ferrari</td>
#       <td id="T_e486c_row9_col1" class="data row9 col1" >159</td>
#     </tr>
#   </tbody>
# </table>
